# %% [markdown]
# ### ================= IMPORTS =================

# %%
import sys
import os

sys.path.append(os.path.abspath("."))
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"D:\Additional-projects\End-to-End-heart-disease-classification\heart.csv")

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# 1         0   0     3       0
# 2         0   0     3       0
# 3         2   1     3       0
# 4         1   3     2       0
# ...     ...  ..   ...     ...
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0
#
# [1025 rows x 14 columns]

# %%
X = df.drop('target', axis=1)
y = df['target']

# %%
from sklearn.model_selection import train_test_split

X_train , X_test , y_train , y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# ================= PROBABILISTIC =================
def naive_bayes(X_train, y_train):
    model = GaussianNB()
    model.fit(X_train, y_train)
    return model


def logistic_regression(X_train, y_train):
    model = LogisticRegression(max_iter=1000)
    model.fit(X_train, y_train)
    return model


# ================= TREE BASED =================
def decision_tree(X_train, y_train):
    model = DecisionTreeClassifier()
    model.fit(X_train, y_train)
    return model


# ================= ENSEMBLE =================
def random_forest(X_train, y_train):
    model = RandomForestClassifier(n_estimators=100)
    model.fit(X_train, y_train)
    return model


def gradient_boosting(X_train, y_train):
    model = GradientBoostingClassifier()
    model.fit(X_train, y_train)
    return model


def xgboost_model(X_train, y_train):
    model = XGBClassifier(
        n_estimators=100,
        learning_rate=0.1,
        max_depth=5,
        use_label_encoder=False,
        eval_metric='logloss'
    )
    model.fit(X_train, y_train)
    return model

# ================= OTHER MODELS =================
def svm_model(X_train, y_train):
    model = SVC()
    model.fit(X_train, y_train)
    return model

# %%
import os
print(os.listdir())
# Out:
# ['ml_models.py', 'Models.ipynb', '__pycache__']

# %%
from ml_models import get_model
from sklearn.metrics import accuracy_score

# ================= CLASSIFICATION =================
MODEL_LIST = [
    "naive_bayes",
    "logistic_regression",
    "decision_tree",
    "random_forest",
    "gradient_boosting",
    "svm",
    "xgboost"
]

# ================= REGRESSION =================
REGRESSION_MODELS = [
    "linear_regression",
    "ridge",
    "lasso",
    "decision_tree",
    "random_forest",
    "gradient_boosting",
    "svr",
    "xgboost"
]

# %%
for model_name in MODEL_LIST:
    
    model = get_model(model_name, X_train, y_train)
    
    # 🔽 STEP 1: prediction
    y_pred = model.predict(X_test)
    
    # 🔽 STEP 2: FIX for XGBoost (ADD HERE)
    if model_name == "xgboost":
        y_pred = (y_pred > 0.5).astype(int)
    
    acc = accuracy_score(y_test, y_pred)
    
    print(f"{model_name} Accuracy: {acc:.4f}")
# Out:
# naive_bayes Accuracy: 0.8634
# logistic_regression Accuracy: 0.8439
# decision_tree Accuracy: 0.9805
# random_forest Accuracy: 1.0000
# gradient_boosting Accuracy: 0.9707
# svm Accuracy: 0.9317
# xgboost Accuracy: 1.0000

# %%
import sys

sys.path.append("D:/Testing_models/regression")

from sklearn.metrics import mean_squared_error, r2_score
from regression_models import get_regression_model



for model_name in REGRESSION_MODELS:
    model = get_regression_model(model_name, X_train, y_train)
    
    y_pred = model.predict(X_test)
    
    mse = mean_squared_error(y_test, y_pred)
    r2 = r2_score(y_test, y_pred)
    
    print(f"{model_name}")
    print(f"→ MSE: {mse:.4f}, R2: {r2:.4f}")
    print()
# Out:
# linear_regression
# → MSE: 0.1205, R2: 0.5176
#
# ridge
# → MSE: 0.1205, R2: 0.5177
#
# lasso
# → MSE: 0.2509, R2: -0.0040
#
# decision_tree
# → MSE: 0.0195, R2: 0.9219
#
# random_forest
# → MSE: 0.0096, R2: 0.9615
#
# gradient_boosting
# → MSE: 0.0557, R2: 0.7772
#
# svr
# → MSE: 0.0372, R2: 0.8512
#
# xgboost
# → MSE: 0.0078, R2: 0.9686

# %%
print(type(y_train[0]), y_train[:5])
# Out:
# <class 'numpy.int64'> 172    1
# 128    1
# 363    1
# 636    0
# 798    0
# Name: target, dtype: int64
